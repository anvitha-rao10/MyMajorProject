# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import LabelEncoder
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anvit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anvit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\anvit\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv('resume.csv')

# %%
df.head()
# Out:
#    ID            Job Title                                             Skills
# 0   1    Software Engineer  Python, Java, SQL, C++, Git, REST APIs, Docker...
# 1   2      Project Manager  Project Management, CAD, MATLAB, Agile, Scrum,...
# 2   3  Electrical Engineer  Circuit Design, Python, Simulink, PLC, PCB Des...
# 3   4         Data Analyst  Python, SQL, Tableau, R, Excel, Data Visualiza...
# 4   5  Structural Engineer  AutoCAD, Revit, Project Management, Structural...

# %%
df.shape
# Out:
# (700, 3)

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# Blockchain Developer              5
# Social Media Manager              4
# Scrum Master                      4
# Data Engineer                     4
# Front-End Developer               4
#                                  ..
# Front-End React Developer         1
# Cloud Support Specialist          1
# Chief Technology Officer (CTO)    1
# Game Programmer                   1
# Key Account Manager               1
# Name: count, Length: 522, dtype: int64

# %%
top_n = 20  
top_jobs = df['Job Title'].value_counts().nlargest(top_n).index
filtered_df = df[df['Job Title'].isin(top_jobs)]

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Job Title', data=filtered_df, order=top_jobs)
plt.xticks(rotation=90)
plt.show()

# %%
df['Job Title'].unique()
# Out:
# array(['Software Engineer', 'Project Manager', 'Electrical Engineer',
#        'Data Analyst', 'Structural Engineer', 'Web Developer',
#        'Machine Learning Engineer', 'Database Administrator',
#        'Cybersecurity Analyst', 'Marketing Specialist',
#        'Mobile App Developer', 'Cloud Solutions Architect',
#        'Financial Analyst', 'UX/UI Designer', 'DevOps Engineer',
#        'Business Analyst', 'Human Resources Specialist',
#        'Mechanical Engineer', 'Quality Assurance Engineer',
#        'Content Writer', 'Network Engineer', 'Sales Manager',
#        'Graphic Designer', 'IT Support Specialist', 'Front-End Developer',
#        'Data Scientist', 'Product Manager', 'Systems Analyst',
#        'Biomedical Engineer', 'Supply Chain Analyst',
#        'Environmental Scientist', 'E-commerce Specialist',
#        'Artificial Intelligence Engineer', 'Game Developer',
#        'Operations Manager', 'Social Media Manager', 'Research Scientist',
#        'Financial Planner', 'Robotics Engineer',
#        'Human Resources Manager', 'Blockchain Developer',
#        'Technical Writer', 'Logistics Coordinator', 'SEO Specialist',
#        'Cloud Engineer', 'Chemist', 'Electrical Technician', 'Paralegal',
#        'Event Planner', 'Agronomist', 'Software Architect',
#        'Scrum Master', 'System Administrator', 'Content Strategist',
#        'Database Engineer', 'Cloud Consultant',
#        'Digital Marketing Specialist', 'Mobile UX/UI Designer',
#        'Network Administrator', 'Data Engineer',
#        'Cloud Security Engineer', 'Marketing Manager',
#        'Security Consultant', 'IT Project Manager',
#        'Machine Learning Researcher',
#        'Artificial Intelligence Researcher', 'Network Security Engineer',
#        'Cloud DevOps Engineer', 'JavaScript Developer',
#        'Python Developer', 'Cloud Solutions Consultant',
#        'IT Security Analyst', 'Web Designer', 'Embedded Systems Engineer',
#        'IT Support Technician', 'Marketing Analyst', 'SEO Analyst',
#        'Data Visualization Specialist', 'Full Stack Developer',
#        'Cloud Infrastructure Engineer', 'Technical Support Engineer',
#        'IT Director', 'Systems Engineer', 'Mechanical Designer',
#        'Senior Software Engineer', 'Cloud Systems Administrator',
#        'Digital Product Manager', 'Application Support Analyst',
#        'Cloud Operations Engineer', 'DevOps Architect',
#        'Data Science Consultant', 'Python Data Engineer',
#        'Marketing Data Analyst', 'Software Quality Engineer',
#        'IT Infrastructure Engineer', 'Research and Development Engineer',
#        'Agile Coach', 'CRM Specialist', 'Blockchain Architect',
#        'Product Designer', 'Video Game Tester', 'Data Security Analyst',
#        'Database Architect', 'Health and Safety Officer', 'IT Auditor',
#        'Site Reliability Engineer', 'SAP Consultant',
#        'Environmental Consultant', 'Audio Engineer', 'Voice UX Designer',
#        'Cloud Data Engineer', 'Front-End UI Developer', 'Content Manager',
#        'Embedded Software Developer', 'Research Associate',
#        'IT Consultant', 'CRM Developer',
#        'Marketing Communications Manager', 'Game Designer',
#        'Research Engineer', 'Mobile Game Developer',
#        'Electrical Design Engineer', 'Industrial Engineer',
#        'Java Developer', 'Legal Consultant', 'Risk Manager',
#        'Art Director', 'Marketing Executive', 'SEO Manager',
#        'Site Manager', 'Operations Analyst',
#        'Digital Transformation Lead', 'Audio-Visual Technician',
#        'Data Governance Specialist', 'Talent Acquisition Manager',
#        'AI Product Manager', 'HR Generalist', 'Procurement Manager',
#        'Financial Controller', 'Commercial Manager',
#        'Corporate Strategy Analyst', 'Data Center Engineer',
#        'Python Software Engineer', 'Principal Data Scientist',
#        'UX Researcher', 'Pharmaceutical Scientist',
#        'SAP Basis Consultant', 'Data Protection Officer',
#        'Product Marketing Manager', 'Solutions Architect',
#        'Data Architect', 'Director of Engineering',
#        'Data Science Manager', 'Operations Coordinator',
#        'JavaScript Engineer', 'Cloud Security Architect',
#        'Lead Data Scientist', 'Brand Manager', 'Community Manager',
#        'E-commerce Manager', 'Junior Data Analyst', 'Head of Operations',
#        'Senior IT Manager', 'Data Entry Clerk', 'Enterprise Architect',
#        'Quality Assurance Lead', 'Project Coordinator',
#        'Mobile App Designer', 'Risk Analyst', 'SEO Content Writer',
#        'AI Engineer', 'Marketing Communications Specialist',
#        'Business Intelligence Analyst', 'Cloud Developer',
#        'Data Migration Specialist', 'IT Security Specialist',
#        'User Interface Designer', 'Content Editor',
#        'Data Operations Analyst', 'Sales Engineer', 'Video Editor',
#        'Senior Web Developer', 'Technical Account Manager',
#        'Product Owner', 'SAP Project Manager', 'Cyber Forensics Expert',
#        'HR Manager', 'Senior Cloud Architect',
#        'Application Security Engineer', 'Technical Support Specialist',
#        'IT Operations Manager', 'Data Quality Analyst',
#        'Senior Python Developer', 'Marketing Automation Specialist',
#        'Security Analyst', 'Scrum Product Owner',
#        'Senior DevOps Engineer', 'Digital Marketing Manager',
#        'QA Engineer', 'Application Architect', 'IT Support Engineer',
#        'Customer Support Engineer', 'Business Systems Analyst',
#        'SAP Business Analyst', 'Junior Data Scientist',
#        'Cloud Operations Manager', 'IT Security Consultant',
#        'Enterprise IT Architect', 'Business Intelligence Developer',
#        'Full Stack Web Developer', 'Digital Transformation Manager',
#        'User Experience Designer', 'Software Development Manager',
#        'Cloud Migration Specialist', 'Backend Developer',
#        'Cloud Security Consultant', 'AI Researcher', 'IT Service Manager',
#        'Robotics Technician', 'E-commerce Developer', 'IT Risk Manager',
#        'IT Compliance Specialist', 'Web Applications Developer',
#        'Penetration Tester', 'IT Manager', 'Senior UX/UI Designer',
#        'Cloud Support Engineer', 'IT Operations Analyst',
#        'Mobile Solutions Architect', 'Game Programmer',
#        'Chief Technology Officer (CTO)', 'Cloud Support Specialist',
#        'Front-End React Developer', 'Technical Program Manager',
#        'Business Intelligence Consultant', 'Data Protection Specialist',
#        'Cloud Solutions Engineer', 'Automation Tester',
#        'Data Center Technician', 'Ethical Hacker',
#        'IT Security Architect', 'Video Game Designer',
#        'Systems Administrator', 'Cloud Architect',
#        'Digital Transformation Specialist', 'IT Help Desk Technician',
#        'Cloud Network Engineer', 'IT Infrastructure Manager',
#        'Application Support Engineer', 'Senior Front-End Developer',
#        'Web Accessibility Specialist', 'ServiceNow Developer',
#        'Machine Vision Engineer', 'IT Change Manager',
#        'DevOps Consultant', 'Technical Project Manager',
#        'Salesforce Developer', 'Business Systems Consultant',
#        'Game AI Developer', 'Big Data Engineer',
#        'IT System Administrator', 'SEO Content Specialist',
#        'Web Application Security Analyst', 'Data Mining Engineer',
#        'User Interface Developer', 'Integration Developer',
#        'Backend Python Developer', 'Cloud Service Manager',
#        'Virtualization Specialist', 'Embedded Software Engineer',
#        'IT Compliance Analyst', 'Network Solutions Architect',
#        'Technology Integration Manager', 'Python Automation Engineer',
#        'Business Operations Analyst', 'IT Training Specialist',
#        'Cybersecurity Architect', 'Senior Data Engineer',
#        'IT Systems Architect', 'Customer Success Manager',
#        'Data Privacy Officer', 'Chief Information Officer (CIO)',
#        'SAP FICO Consultant', 'AI Solutions Architect',
#        'Mobile App UI/UX Designer', 'SAP HANA Consultant',
#        'Salesforce Administrator', 'System Integration Engineer',
#        'Digital Forensics Expert', '3D Artist', 'IT Project Coordinator',
#        'QA Automation Engineer', 'Business Process Analyst',
#        'UI Designer', 'Full Stack JavaScript Developer',
#        'Web Content Strategist', 'Ethical AI Specialist',
#        'Technical Account Executive', 'Cloud Systems Architect',
#        'Data Privacy Specialist', 'Agile Scrum Master',
#        'IT Business Analyst', 'Embedded Systems Developer',
#        'Data Center Operations Manager', 'IT Compliance Manager',
#        'Infrastructure Engineer', 'API Developer', 'UX/UI Developer',
#        'IoT Solutions Engineer', 'HR Coordinator', 'Event Coordinator',
#        'Tax Auditor', 'Fashion Stylist', 'Commercial Pilot',
#        'Flight Dispatcher', 'Cinematographer',
#        'Clinical Research Coordinator', 'Loan Officer',
#        'Business Development Manager', 'Park Ranger',
#        'Construction Foreman', 'Occupational Therapist',
#        'Insurance Underwriter', 'Medical Laboratory Technician',
#        'Executive Assistant', 'Maintenance Technician',
#        'Pharmacovigilance Specialist', 'Construction Estimator',
#        'Economist', 'Legal Secretary', 'Executive Chef',
#        'Physical Therapist Assistant', 'Labor Relations Specialist',
#        'Sports Coach', 'Landscape Architect', 'Executive Director',
#        'Property Manager', 'Supply Chain Manager', 'Optometrist',
#        'Director of Operations', 'Market Research Analyst',
#        'Public Health Specialist', 'Architect of Record',
#        'Food Safety Specialist', 'Retail Manager', 'Art Therapist',
#        'Client Relations Manager', 'Payroll Specialist',
#        'Health Insurance Specialist', 'Legal Counsel',
#        'Strategic Planner', 'Clinical Psychologist',
#        'Management Consultant', 'Social Worker',
#        'Aircraft Maintenance Technician', 'Personal Trainer', 'Dietitian',
#        'Public Relations Specialist', 'Construction Manager',
#        'Real Estate Agent', 'Research Analyst', 'Procurement Specialist',
#        'Travel Agent', 'Museum Curator', 'Event Manager', 'Tour Guide',
#        'Interpreter', 'Psychologist', 'Nurse',
#        'Physical Education Teacher', 'Speech-Language Pathologist',
#        'Architect', 'Catering Manager', 'Editor', 'Bartender',
#        'Massage Therapist', 'Firefighter', 'Plumber', 'Electrician',
#        'Photographer', 'Baker', 'Chef', 'Event Designer',
#        'Childcare Worker', 'Veterinarian', 'Teacher', 'Janitor',
#        'Security Guard', 'Landscaping Worker', 'Construction Laborer',
#        'Taxi Driver', 'Waiter', 'Maid', 'Housekeeper', 'Bus Driver',
#        'Taxi Dispatcher', 'Construction Surveyor', 'Carpet Cleaner',
#        'Roofer', 'Crane Operator', 'Elevator Installer',
#        'Heavy Equipment Operator', 'Truck Driver', 'Forklift Operator',
#        'Warehouse Worker', 'Dental Hygienist', 'Chiropractor',
#        'Radiologic Technologist', 'Pharmacist', 'Physician Assistant',
#        'Nurse Practitioner', 'Psychiatrist', 'Paramedic',
#        'Physical Therapist', 'Dental Assistant',
#        'Certified Nursing Assistant', 'Home Health Aide',
#        'Surgical Technologist', 'Medical Biller/Coder',
#        'Ambulance Driver', 'EMT (Emergency Medical Technician)',
#        'Veterinarian Technician', 'Animal Caretaker', 'Zookeeper',
#        'Animal Trainer', 'Agricultural Engineer', 'Farm Manager',
#        'Horticulturist', 'Fishery Manager', 'Arborist',
#        'Geotechnical Engineer', 'Hydrologist', 'Environmental Engineer',
#        'Waste Management Specialist', 'Climate Scientist',
#        'Conservation Biologist', 'Marine Biologist', 'Crossfit Trainer',
#        'Yoga Instructor', 'Pilates Instructor', 'Zumba Instructor',
#        'Personal Chef', 'Restaurant Manager', 'Hotel Manager',
#        'Concierge', 'Front Desk Receptionist', 'Sous Chef', 'Pastry Chef',
#        'Restaurant Owner', 'Civil Engineer', 'Surveyor', 'Urban Planner',
#        'Facilities Manager', 'Speech Therapist', 'Dentist',
#        'Medical Assistant', 'Registered Nurse', 'Surgeon',
#        'Laboratory Technician', 'Radiologist', 'Anesthesiologist',
#        'Dermatologist', 'Speech Pathologist', 'Nutritionist',
#        'Fitness Instructor', 'Acupuncturist', 'Pet Groomer', 'Farmer',
#        'Forestry Technician', 'Urban Farmer', 'Agricultural Consultant',
#        'Commercial Fisherman', 'Fishery Biologist', 'Biochemist',
#        'Microbiologist', 'Geneticist', 'Botanist', 'Biologist',
#        'Ecologist', 'Pharmacologist', 'Toxicologist', 'Soil Scientist',
#        'Geologist', 'Geophysicist', 'Cartographer', 'Urban Designer',
#        'Transportation Planner', 'Distribution Manager',
#        'Warehouse Manager', 'Fleet Manager', 'Inventory Manager',
#        'Import/Export Coordinator', 'Purchasing Agent',
#        'Shipping Coordinator', 'Production Manager', 'Factory Worker',
#        'Quality Control Inspector', 'Production Assistant',
#        'Mechanical Technician', 'Manufacturing Technician',
#        'CNC Machinist', 'Tool and Die Maker', 'Industrial Designer',
#        'Prototype Technician', 'Manufacturing Engineer',
#        'Aerospace Engineer', 'Nuclear Engineer', 'Chemical Engineer',
#        'Materials Engineer', 'Petroleum Engineer', 'Mining Engineer',
#        'Marine Engineer', 'Landscape Designer', 'Interior Designer',
#        'Video Producer', 'Animator', 'Illustrator', 'Copywriter',
#        'Content Creator', 'Fundraising Coordinator', 'Account Executive',
#        'Key Account Manager'], dtype=object)

# %%
top_n = 10  # Number of top job titles to include
counts = df['Job Title'].value_counts()
top_counts = counts[:top_n]  # Select the top 'n' job titles

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 8))
plt.pie(top_counts, labels=top_counts.index, autopct='%1.1f%%', shadow=True,
        colors=plt.cm.plasma(np.linspace(0, 1, len(top_counts))))
plt.show()

# %%
def clean_text(txt):
    clean_text = re.sub('http\S+\s', ' ', txt)
    clean_text = re.sub('RT|cc', ' ', clean_text)
    clean_text = re.sub('#\S+\s', ' ', clean_text)
    clean_text = re.sub('@\S+', '  ', clean_text)
    clean_text = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', clean_text)
    clean_text = re.sub(r'[^\x00-\x7f]', ' ', clean_text)
    clean_text = re.sub('\s+', ' ', clean_text)
    tokens = nltk.word_tokenize(clean_text.lower())
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words and word.isalpha()]
    return ' '.join(tokens)

# %%
df['cleaned_job_title'] = df['Job Title'].apply(clean_text)
df['cleaned_skills'] = df['Skills'].apply(clean_text)

# %%
def clean_resume(txt):
    return clean_text(txt)

# %%
resume_text = """Anvitha G Rao
+91-9480199605/+91-7892821940
anvitha8181@gmail.com
Linkedin : http://www.linkedin.com/in/anvitha-g-rao-ab529324b Github : https://github.com/anvitha-rao10
Sripada, Hari Om Nivas, Urwa, Mangalore-575006
SUMMARY
A Computer Science and Engineering student specializing in IoT, Cyber Security, Blockchain Technology, AIML, and Full Stack Development, passionate about developing interconnected systems that leverage the power of IoT to enhance efficiency and foster innovation. I am eager to contribute my knowledge and enthusiasm to a progressive team during my internship.
EDUCATION
B.E - CSE (IOT & Cyber Security with Block Chain Technology)
Mangalore Institute of Technology & Engineering
2021-Present
CGPA:9.1
Senior Secondary (12th) – Boscoss PU College, Mangalore
2019-2021
Percentage:90%
Secondary School (SSLC) – Canara High School, Mangalore
2018-2019
Percentage:85%
SKILLS
Languages
: Java, C language, Python, HTML, CSS
Database
: SQL
Tools
: MySQL, Visual Studio Code, Postman, IntelliJ, Arduino IDE, Spring Boot
Soft Skills
: Communication, Teamwork, Work ethics, Problem-solving, Time Management, Emotional Intelligence.
INTERNSHIP
Glowtouch Technologies | FrontendDeveloper October-2023 to November-2023 Technologies: Angular Js, NodeJs, MySQL, Postman, Spring Boot
Worked on a Project - ‘Ecommerce Platform’, gained experience in Back-end Development using Angular Js, Node Js, MySQL, Postman. Also, learnt about how Ecommerce works.
PROJECTS
• IoT Based smart fire detection and alert system | Group of 3 November-2022 Technologies: Arduino UNO, Sensors, Actuators.
The aim of this project is to enhance safety and minimize damage by providing early detection and immediate alerts of fire incidents.
• Crop Disease Detection System | Group of 4 May-2024 Technologies: TensorFlow Framework, Keras Framework, Streamlit.
The aim of this project is to use machine learning to accurately identify crop diseases early, enhancing agricultural productivity and reducing crop losses.
COURSES & WORKSHOPS
• Introduction To Industry 4.0 And Industrial Internet of Things - Certified by IIT Kharagpur
• Database Management System -Certified by IIT Kharagpur
• TalentNext Course on Java Full Stack -Certified by Wipro
• Blockchain and Dapps Development for cybersecurity - Mangalore Institute of Technology and Engineering
• Innovation & Inventions on Autonomous Vehicle - Mangalore Institute of Technology and Engineering
• Cybersecurity - Google and SmartKnower
• Academic Automation Explorer Training - Ui Path
• Cyber Defense Engineering using Python – Certified by Cybervidyapeeth Foundation
• Introduction to Information Security - Great Learning
• MATLAB Onramp – Matworks | Training Service
• Cybersecurity and Ethical Hacking – Reinfosec, Bangalore
TECHNICAL ACTIVITIES
• Participated in Codify and secured 2nd place.
• Served as Secretary of CYBOTIC
EXTRA CURRICULAR & HOBBIES
• Reading novels, Dance and Music, Needlecraft."""
cleaned_resume = clean_resume(resume_text)

# %%
df['job_description'] = df['cleaned_job_title'] + ' ' + df['cleaned_skills']

# %%
vectorizer = TfidfVectorizer(max_features=5000)
job_vectors = vectorizer.fit_transform(df['job_description']).toarray()

# %%
knn = NearestNeighbors(n_neighbors=5, metric='cosine')
knn.fit(job_vectors)
# Out:
# NearestNeighbors(metric='cosine')

# %%
resume_vector = vectorizer.transform([cleaned_resume]).toarray()
distances, indices = knn.kneighbors(resume_vector)

# %%
top_5_jobs = df.iloc[indices[0]]

print("\nTop 5 Matching Job Titles:")
for i, row in top_5_jobs.iterrows():
    print(f"- {row['Job Title']} (Matched Skills: {row['Skills']})")
# Out:
# Top 5 Matching Job Titles:
# - Chief Technology Officer (CTO) (Matched Skills: IT Strategy, Technology Leadership, Cloud, Software Development, Team Management)
# - Director of Engineering (Matched Skills: Engineering Management, Project Oversight, System Design, Architecture, Leadership)
# - IoT Solutions Engineer (Matched Skills: IoT, Embedded Systems, Python, Hardware Design, Cloud Computing, Networking)
# - Technology Integration Manager (Matched Skills: Integration Strategy, Systems Integration, Project Management, APIs, Cloud Computing)
# - Research and Development Engineer (Matched Skills: R&D, Innovation, Product Design, Prototyping, CAD, Engineering, MATLAB)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

job_titles = top_5_jobs['Job Title']
skills_count = [len(skills.split(', ')) for skills in top_5_jobs['Skills']]

plt.figure(figsize=(10, 6))
sns.barplot(x=job_titles, y=skills_count, palette='viridis')
plt.title('Top 5 Job Matches for the Resume', fontsize=16)
plt.xlabel('Job Titles', fontsize=14)
plt.xticks(rotation=90)
plt.ylabel('Number of Skills Matched', fontsize=14)
plt.tight_layout()
plt.show()
